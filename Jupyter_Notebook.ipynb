# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Gustavo Muller**
#
# Industrial Engineer

# %% [markdown]
# *I am interested in data science because I would like to apply it to my area of work (engineering), and in this way be able to optimize processes, and also economic resources.*

# %% [markdown]
# ### I create a variable, which sum 1 plus 1, then print the result of that sum.

# %%
sumatoria = 1 + 1
print(sumatoria)
# Out:
# 2

# %% [markdown]
# > 1 + 1 is 2 !
#
# 1. Create Variable
#     * Add digits
# 2. Print the result
#
# [This course link](www.coursera.org/learn/open-source-tools-for-data-science)
